# %% [markdown]
# Source:
# Github of Isabel Segura Bedmar
# https://github.com/isegura/BasicNLP

# %% [markdown]
# ## Connect Drive

# %%
from google.colab import drive
drive.mount("/content/drive/")
# !ls
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/
# drive  sample_data

# %% [markdown]
# # Import libraries

# %%
#dataframes
import pandas as pd
from tabulate import tabulate

#regex
import re

# %% [markdown]
# #Input

# %% [markdown]
# Data source :
# Version 1.3 10.5281/zenodo.3758054 	Jan 23, 2020
#
# Colaboratory folder : Codiespv2/datasetv3
#
#
# >T1. datasetv3/train/text_files/...
#
# >T2. datasetv3/dev/text_files/...
#
# >T3. datasetv3/test/text_files/...
#
# >T4. datasetv3/train/text_files_en/...
#
# >T5. datasetv3/dev/text_files_en/...
#
# >T6. datasetv3/test/text_files_en/...

# %% [markdown]
# #Create a tsv from all text files

# %%
def extract_text_files(list):
  #print(list)
  df = pd.DataFrame(data=list)
  texts=[]
  for text in list:      
    text_divided = (text.split())  #separate two elements by /s
    for elements in text_divided:
      texts.append(elements)   #join all the elements in a list
  print(texts)  
  return(texts)

def list_content_text_file(file_name_list, path):
  files_content = []
  for element in file_name_list:
    path_element = path + element   
    #print(element) #name of a file_name
    content_element = open(path_element).read()
    files_content.append(content_element)
    #print(content_element)
  #print(files_content)
  return files_content

def df_text_file(articles_id, articles_content, dataset_path):
   # Calling DataFrame constructor after zipping both lists, with columns specified 
  df = pd.DataFrame(list(zip(articles_id, articles_content)), 
               columns =['article_id', 'article_content']) 

  print("--- Loaded dataset:", dataset_path)
  print("--- Number of rows is " + str(df.shape[0]) + " x number of columns " + str(df.shape[1]))
  #print(df.head())
  print(tabulate(df.head(), headers='keys', tablefmt='psql'))
  return df

def cut_textfile_name(text_list):    
  article_id_list = []
  for file_name in text_list:
    article_id_list.append(file_name.rstrip(".txt"))
  return article_id_list

# %% [markdown]
# ###Text_files (train)

# %% [markdown]
# ####Extract Text_files (train) from directory to dataframe

# %%
cd
# Out:
# /root

# %%
cd '/content/drive/My Drive/Colab Notebooks/3. Codiesp/Codiespv2/datasetv3/train/text_files'
# Out:
# /content/drive/My Drive/Colab Notebooks/3. Codiesp/Codiespv2/datasetv3/train/text_files

# %%
#!ls

# %%
train_text_file_list = !ls         #Copy all the files

# %%
train_text_list = extract_text_files(train_text_file_list)
train_path_text_list = '/content/drive/My Drive/Colab Notebooks/3. Codiesp/Codiespv2/datasetv3/train/text_files/'
train_articles_content = list_content_text_file(train_text_list, train_path_text_list)
train_article_id_list= cut_textfile_name(train_text_list)    #It erases .txt from the text files names in order to obtain articleID
#print(train_article_id_list)

print("- Load Text Files")
df_train_textfiles = df_text_file(train_article_id_list, train_articles_content, train_path_text_list)
# Out:
# ['S0004-06142005000700014-1.txt', 'S0378-48352006000600006-1.txt', 'S0004-06142005000900013-1.txt', 'S0378-48352006000900006-1.txt', 'S0004-06142005000900015-1.txt', 'S0465-546X2008000200010-1.txt', 'S0004-06142005001000011-3.txt', 'S0465-546X2009000300008-1.txt', 'S0004-06142005001000016-1.txt', 'S0465-546X2011000300007-1.txt', 'S0004-06142006000100014-1.txt', 'S0465-546X2014000300010-1.txt', 'S0004-06142006000200001-1.txt', 'S1130-01082004001200010-1.txt', 'S0004-06142006000200013-1.txt', 'S1130-01082005001000014-1.txt', 'S0004-06142006000200014-1.txt', 'S1130-01082005001200011-1.txt', 'S0004-06142006000300015-1.txt', 'S1130-01082005001200013-1.txt', 'S0004-06142006000500002-2.txt', 'S1130-01082006000100014-1.txt', 'S0004-06142006000500011-1.txt', 'S1130-01082006000700014-1.txt', 'S0004-06142006000600009-1.txt', 'S1130-01082007000300006-7.txt', 'S0004-06142006000600012-1.txt', 'S1130-01082007000400015-1.txt', 'S0004-06142006000700013-1.txt', 'S1130-01082007000600012-1.txt', 'S0004-
# ...

# %% [markdown]
# ####Save Text_files (train) dataframe as tsv

# %%
cd
# Out:
# /root

# %%
df_train_textfiles.to_csv('/content/drive/My Drive/Colab Notebooks/3. Codiesp/Codiespv2/datasetv3/train/train_articles_codiesp.csv', index=False) #guardar dataframe como tsv sin el indice de la izquierda

# %% [markdown]
# ###Text_files (dev)

# %% [markdown]
# ####Extract Text_files (dev) from directory to dataframe

# %%
cd
# Out:
# /root

# %%
cd '/content/drive/My Drive/Colab Notebooks/3. Codiesp/Codiespv2/datasetv3/dev/text_files'
# Out:
# /content/drive/My Drive/Colab Notebooks/3. Codiesp/Codiespv2/datasetv3/dev/text_files

# %%
#!ls

# %%
dev_text_file_list = !ls         #Copy all the files

# %%
dev_text_list = extract_text_files(dev_text_file_list)
dev_path_text_list = '/content/drive/My Drive/Colab Notebooks/3. Codiesp/Codiespv2/datasetv3/dev/text_files/'
dev_articles_content = list_content_text_file(dev_text_list, dev_path_text_list)
dev_article_id_list= cut_textfile_name(dev_text_list)    #It erases .txt from the text files names in order to obtain articleID
#print(dev_article_id_list)

print("- Load Text Files")
df_dev_textfiles = df_text_file(dev_article_id_list, dev_articles_content, dev_path_text_list)
# Out:
# ['S0004-06142005000900016-1.txt', 'S0376-78922017000100008-1.txt', 'S0004-06142005001000011-1.txt', 'S0378-48352004000200007-1.txt', 'S0004-06142006000200011-1.txt', 'S0378-48352004000300007-1.txt', 'S0004-06142006000500002-3.txt', 'S0378-48352004000900006-1.txt', 'S0004-06142006000500002-4.txt', 'S0378-48352005000400004-1.txt', 'S0004-06142006000600015-1.txt', 'S0378-48352005000900005-1.txt', 'S0004-06142006000700008-1.txt', 'S0378-48352006000300006-1.txt', 'S0004-06142006000900008-1.txt', 'S0378-48352006000900004-1.txt', 'S0004-06142006000900009-1.txt', 'S0465-546X2014000400012-1.txt', 'S0004-06142007000300012-1.txt', 'S1130-01082005000500013-1.txt', 'S0004-06142007000600011-1.txt', 'S1130-01082005000800013-1.txt', 'S0004-06142007000700014-1.txt', 'S1130-01082005001100014-1.txt', 'S0004-06142007000700015-1.txt', 'S1130-01082006000900015-1.txt', 'S0004-06142008000100008-1.txt', 'S1130-01082007000100014-1.txt', 'S0004-06142008000300011-1.txt', 'S1130-01082007000500016-1.txt', 'S0004-
# ...

# %% [markdown]
# ####Save Text_files (dev) dataframe as tsv

# %%
cd
# Out:
# /root

# %%
df_dev_textfiles.to_csv('/content/drive/My Drive/Colab Notebooks/3. Codiesp/Codiespv2/datasetv3/dev/dev_articles_codiesp.csv', index=False) #guardar dataframe como tsv sin el indice de la izquierda

# %% [markdown]
# ###Text_files (test)

# %% [markdown]
# ####Extract Text_files (test) from directory to dataframe

# %%
cd
# Out:
# /root

# %%
cd '/content/drive/My Drive/Colab Notebooks/3. Codiesp/Codiespv2/datasetv3/test/text_files'
# Out:
# /content/drive/My Drive/Colab Notebooks/3. Codiesp/Codiespv2/datasetv3/test/text_files

# %%
#!ls

# %%
test_text_file_list = !ls         #Copy all the files

# %%
test_text_list = extract_text_files(test_text_file_list)
test_path_text_list = '/content/drive/My Drive/Colab Notebooks/3. Codiesp/Codiespv2/datasetv3/test/text_files/'
test_articles_content = list_content_text_file(test_text_list, test_path_text_list)
test_article_id_list= cut_textfile_name(test_text_list)    #It erases .txt from the text files names in order to obtain articleID
#print(test_article_id_list)

print("- Load Text Files")
df_test_textfiles = df_text_file(test_article_id_list, test_articles_content, test_path_text_list)
# Out:
# []
# - Load Text Files
# --- Loaded dataset: /content/drive/My Drive/Colab Notebooks/3. Codiesp/Codiespv2/datasetv3/test/text_files/
# --- Number of rows is 0 x number of columns 2
# +--------------+-------------------+
# | article_id   | article_content   |
# |--------------+-------------------|
# +--------------+-------------------+

# %% [markdown]
# ####Save Text_files (test) dataframe as tsv

# %%
cd

# %%
df_test_textfiles.to_csv('/content/drive/My Drive/Colab Notebooks/3. Codiesp/Codiespv2/datasetv3/test/test_articles_codiesp.csv', index=False) #guardar dataframe como tsv sin el indice de la izquierda

# %% [markdown]
# ###Text_files_en (train)

# %% [markdown]
# ####Extract Text_files_en (train) from directory to dataframe

# %%
cd
# Out:
# /root

# %%
cd '/content/drive/My Drive/Colab Notebooks/3. Codiesp/Codiespv2/datasetv3/train/text_files_en'
# Out:
# /content/drive/My Drive/Colab Notebooks/3. Codiesp/Codiespv2/datasetv3/train/text_files_en

# %%
#!ls

# %%
train_text_file_en_list = !ls         #Copy all the files

# %%
train_text_en_list = extract_text_files(train_text_file_en_list)
train_path_text_en_list = '/content/drive/My Drive/Colab Notebooks/3. Codiesp/Codiespv2/datasetv3/train/text_files_en/'
train_articles_en_content = list_content_text_file(train_text_en_list, train_path_text_en_list)
train_article_id_en_list= cut_textfile_name(train_text_en_list)    #It erases .txt from the text files names in order to obtain articleID
#print(train_article_id_en_list)

print("- Load Text Files")
df_train_textfiles_en = df_text_file(train_article_id_en_list, train_articles_en_content, train_path_text_en_list)
# Out:
# ['S0004-06142005000700014-1.txt', 'S0378-48352006000600006-1.txt', 'S0004-06142005000900013-1.txt', 'S0378-48352006000900006-1.txt', 'S0004-06142005000900015-1.txt', 'S0465-546X2008000200010-1.txt', 'S0004-06142005001000011-3.txt', 'S0465-546X2009000300008-1.txt', 'S0004-06142005001000016-1.txt', 'S0465-546X2011000300007-1.txt', 'S0004-06142006000100014-1.txt', 'S0465-546X2014000300010-1.txt', 'S0004-06142006000200001-1.txt', 'S1130-01082004001200010-1.txt', 'S0004-06142006000200013-1.txt', 'S1130-01082005001000014-1.txt', 'S0004-06142006000200014-1.txt', 'S1130-01082005001200011-1.txt', 'S0004-06142006000300015-1.txt', 'S1130-01082005001200013-1.txt', 'S0004-06142006000500002-2.txt', 'S1130-01082006000100014-1.txt', 'S0004-06142006000500011-1.txt', 'S1130-01082006000700014-1.txt', 'S0004-06142006000600009-1.txt', 'S1130-01082007000300006-7.txt', 'S0004-06142006000600012-1.txt', 'S1130-01082007000400015-1.txt', 'S0004-06142006000700013-1.txt', 'S1130-01082007000600012-1.txt', 'S0004-
# ...

# %% [markdown]
# ####Save Text_files_en (train) dataframe as tsv

# %%
cd
# Out:
# /root

# %%
df_train_textfiles_en.to_csv('/content/drive/My Drive/Colab Notebooks/3. Codiesp/Codiespv2/datasetv3/train/train_articles_en_codiesp.csv', index=False) #guardar dataframe como tsv sin el indice de la izquierda

# %% [markdown]
# ###Text_files_en (dev)

# %% [markdown]
# ####Extract Text_files_en (dev) from directory to dataframe

# %%
cd
# Out:
# /root

# %%
cd '/content/drive/My Drive/Colab Notebooks/3. Codiesp/Codiespv2/datasetv3/dev/text_files_en'
# Out:
# /content/drive/My Drive/Colab Notebooks/3. Codiesp/Codiespv2/datasetv3/dev/text_files_en

# %%
·#!ls

# %%
dev_text_file_en_list = !ls         #Copy all the files

# %%
dev_text_en_list = extract_text_files(dev_text_file_en_list)
dev_path_text_en_list = '/content/drive/My Drive/Colab Notebooks/3. Codiesp/Codiespv2/datasetv3/dev/text_files_en/'
dev_articles_en_content = list_content_text_file(dev_text_en_list, dev_path_text_en_list)
dev_article_id_en_list= cut_textfile_name(dev_text_en_list)    #It erases .txt from the text files names in order to obtain articleID
#print(dev_article_id_en_list)

print("- Load Text Files")
df_dev_textfiles_en = df_text_file(dev_article_id_en_list, dev_articles_en_content, dev_path_text_en_list)
# Out:
# ['S0004-06142005000900016-1.txt', 'S0376-78922017000100008-1.txt', 'S0004-06142005001000011-1.txt', 'S0378-48352004000200007-1.txt', 'S0004-06142006000200011-1.txt', 'S0378-48352004000300007-1.txt', 'S0004-06142006000500002-3.txt', 'S0378-48352004000900006-1.txt', 'S0004-06142006000500002-4.txt', 'S0378-48352005000400004-1.txt', 'S0004-06142006000600015-1.txt', 'S0378-48352005000900005-1.txt', 'S0004-06142006000700008-1.txt', 'S0378-48352006000300006-1.txt', 'S0004-06142006000900008-1.txt', 'S0378-48352006000900004-1.txt', 'S0004-06142006000900009-1.txt', 'S0465-546X2014000400012-1.txt', 'S0004-06142007000300012-1.txt', 'S1130-01082005000500013-1.txt', 'S0004-06142007000600011-1.txt', 'S1130-01082005000800013-1.txt', 'S0004-06142007000700014-1.txt', 'S1130-01082005001100014-1.txt', 'S0004-06142007000700015-1.txt', 'S1130-01082006000900015-1.txt', 'S0004-06142008000100008-1.txt', 'S1130-01082007000100014-1.txt', 'S0004-06142008000300011-1.txt', 'S1130-01082007000500016-1.txt', 'S0004-
# ...

# %% [markdown]
# ####Save text files_en (dev) dataframe as tsv

# %%
cd
# Out:
# /root

# %%
df_dev_textfiles_en.to_csv('/content/drive/My Drive/Colab Notebooks/3. Codiesp/Codiespv2/datasetv3/dev/dev_articles_en_codiesp.csv', index=False) #guardar dataframe como tsv sin el indice de la izquierda

# %% [markdown]
# ###Text_files_en (test)

# %% [markdown]
# ####Extract Text_files_en (test) from directory to dataframe

# %%
cd
# Out:
# /root

# %%
cd '/content/drive/My Drive/Colab Notebooks/3. Codiesp/Codiespv2/datasetv3/test/text_files_en'
# Out:
# /content/drive/My Drive/Colab Notebooks/3. Codiesp/Codiespv2/datasetv2/test/text_files_en

# %%
#!ls

# %%
test_text_file_en_list = !ls         #Copy all the files

# %%
test_text_en_list = extract_text_files(test_text_file_en_list)
test_path_text_en_list = '/content/drive/My Drive/Colab Notebooks/3. Codiesp/Codiespv2/datasetv3/test/text_files_en/'
test_articles_en_content = list_content_text_file(test_text_en_list, test_path_text_en_list)
test_article_id_en_list= cut_textfile_name(test_text_en_list)    #It erases .txt from the text files names in order to obtain articleID
#print(test_article_id_en_list)

print("- Load Text Files")
df_test_textfiles_en = df_text_file(test_article_id_en_list, test_articles_en_content, test_path_text_en_list)

# %% [markdown]
# ####Save Text_files_en (test) dataframe as tsv

# %%
cd
# Out:
# /root

# %%
df_train_textfiles_en.to_csv('/content/drive/My Drive/Colab Notebooks/3. Codiesp/Codiespv2/datasetv3/test/test_articles_en_codiesp.csv', index=False) #guardar dataframe como tsv sin el indice de la izquierda

# %% [markdown]
# #Output

# %% [markdown]
# Colaboratoy folder : Codiespv2/datasetv3
#
# >T1. datasetv3/train/train_articles_codiesp.csv
#
# >T2. datasetv3/dev/dev_articles_codiesp.csv
#
# >T3. datasetv3/test/test_articles_codiesp.csv
#
# >T4. datasetv3/train/train_articles_en_codiesp.csv
#
# >T5. datasetv3/dev/dev_articles_en_codiesp.csv
#
# >T6. datasetv3/test/test_articles_en_codiesp.csv
